# %%
from demo_lib.utils import setImportPath
setImportPath()

import matplotlib.pyplot as plt
from operator import itemgetter
import cv2
import traceback
from OZEngine.edge_detectors import Morph, HED
from OZEngine.lib.utils import *
from OZEngine import OmilZomil
# Out:
# dress checker
# OCR loaded!
# /config/workspace/WEB_CLOUD_OhmilZomil_NAVYeffect/AI_BE/demo
# /config/workspace/WEB_CLOUD_OhmilZomil_NAVYeffect/AI_BE/OZEngine/edge_detectors/HED
# /config/workspace/WEB_CLOUD_OhmilZomil_NAVYeffect/AI_BE/OZEngine/person_detectors

# %%
# img = cv2.imread('image/full_dress_uniform/person/17.jpg')
img = cv2.imread('image/video_frame/1/0.jpg')

# resize, img_norm_type, uniform_type, mode=, detect_person
model = OmilZomil(None, 'yCrCb', 'FULL_DRESS', 'debug', True)
# Out:
# [RCF] loading...
# [RCF] finished loading (0.1886 sec)
# init!

# %%
try:
    component_dic, box_position_dic = model.detect(img)
except Exception as e:
    print(e)
    print(traceback.format_exc())

print(component_dic)
# Out:
# 인식가능한 사람이 없습니다!
# Traceback (most recent call last):
#   File "<ipython-input-3-e35a54a8c53e>", line 2, in <module>
#     component_dic, box_position_dic = model.detect(img)
#   File "/config/workspace/WEB_CLOUD_OhmilZomil_NAVYeffect/AI_BE/OZEngine/model.py", line 61, in detect
#     raise Exception("인식가능한 사람이 없습니다!")
# Exception: 인식가능한 사람이 없습니다!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e35a54a8c53e> in <module>
#       5     print(traceback.format_exc())
#       6
# ----> 7 print(component_dic)
#
# NameError: name 'component_dic' is not defined
